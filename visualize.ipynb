# %%
from visualizer import plot_graph, plot_year
import pandas as pd
import matplotlib.pyplot as plt

# %%
TRAIN = 'data/train.csv'
TEST = 'data/test.csv'
train_data = pd.read_csv(TRAIN)
test_data = pd.read_csv(TEST)

# %% [markdown]
# ## YEAR PLOTTING

# %%
train_data['DATE'] = train_data['DATE'].astype('datetime64[ns]')
train_data = train_data.sort_values(by='DATE', ascending=True)

# %%
plt.figure(figsize=(30, 10))
for i in range(2010, 2020):
    plot_year(train_data, i)

# %% [markdown]
# ## RELATIONSHIP

# %%
plot_graph(train_data)
# Out:
# /home/tuanhuynh/College/Year 2/Mathematics Stats/climate-predictor/visualizer.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(1, 3)
