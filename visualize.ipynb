# %%
from visualizer import plot_graph, plot_year
import pandas as pd
import matplotlib.pyplot as plt

# %%
TRAIN = 'data/train.csv'
TEST = 'data/test.csv'
train_data = pd.read_csv(TRAIN)
test_data = pd.read_csv(TEST)

# %% [markdown]
# ## YEAR PLOTTING

# %%
train_data['DATE'] = train_data['DATE'].astype('datetime64[ns]')
train_data = train_data.sort_values(by='DATE', ascending=True)

# %%
mask = (train_data['DATE'] >= f'{2010}-01-01') & (train_data['DATE'] < f'{2021}-01-01')
_df = train_data.loc[mask]
_df[['TAVG']].describe()
# Out:
#              TAVG
# count  500.000000
# mean    10.341200
# std      7.287425
# min     -8.870000
# 25%      6.460000
# 50%      7.190000
# 75%     12.125000
# max     29.620000

# %%
plt.figure(figsize=(30, 10))
plot_year(train_data, 2010, 2020)

# %%
plt.figure(figsize=(30, 10))
plot_year(train_data, 2010, 2010)

# %% [markdown]
# ## RELATIONSHIP

# %%
plot_graph(train_data)
# Out:
# /mnt/d/Learning/University/Toán ứng dụng và thống kê/Main-Project-1/climate-predictor/visualizer.py:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(1, 3)
