# %%
from visualizer import plot_year, describe_data, scatterplot_year
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
matplotlib.__version__
# Out:
# '3.3.4'

# %%
TRAIN = '../data/train.csv'
TEST = '../data/test.csv'
train_data = pd.read_csv(TRAIN)
test_data = pd.read_csv(TEST)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-5c776d07e7cc> in <module>
#       1 TRAIN = 'data/train.csv'
#       2 TEST = 'data/test.csv'
# ----> 3 train_data = pd.read_csv(TRAIN)
#       4 test_data = pd.read_csv(TEST)
#
# ...

# %% [markdown]
# ## YEAR PLOTTING

# %%
plot_year(test_data, 2005, 2014, '1.png')
plot_year(test_data, 2010, 2010, '2.png')
scatterplot_year(test_data, 2005, 2014, '3.png')
describe_data(test_data, 2005, 2014)
# Out:
#              TAVG
# count  914.000000
# mean    21.614551
# std      3.505322
# min     12.900000
# 25%     18.750000
# 50%     22.405000
# 75%     24.315000
# max     28.160000

# %%
plot_graph(train_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-be16748e723b> in <module>
# ----> 1 plot_graph(train_data)
#
# /mnt/d/Learning/University/Toán ứng dụng và thống kê/Main-Project-1/climate-predictor/visualizer.py in plot_graph(df)
#      19         fig.set_size_inches(25.5, 8.5)
#      20         sns.regplot(ax=axes[0], x=valid_col, y="TMIN", **kwargs)
# ---> 21         sns.regplot(ax=axes[1], x=valid_col, y="TMAX", **kwargs)
#      22         sns.regplot(ax=axes[2], x=valid_col, y="TAVG", **kwargs)
#      23         fig.suptitle(valid_col, fontsize=20)
#
# ~/.local/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
