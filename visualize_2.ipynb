# %%
from src_2.visualizer import plot_year, describe_data, scatterplot_year
import pandas as pd
import matplotlib
import seaborn as sns
matplotlib.__version__
# Out:
# '3.4.2'

# %%
TRAIN = 'data/train.csv'
TEST = 'data/test.csv'
train_data = pd.read_csv(TRAIN)
test_data = pd.read_csv(TEST)

# %% [markdown]
# ### Nhiệt độ trung bình từ năm 2005 - 2014

# %%
plot_year(test_data, 2005, 2014, '1.png')

# %% [markdown]
# ### Nhiệt độ trung bình trong năm trong năm 2010

# %%
plot_year(test_data, 2010, 2010, '2.png')

# %% [markdown]
# ### Biểu đồ phân tán

# %%
scatterplot_year(test_data, 2005, 2014, '3.png')

# %%
describe_data(test_data, 2005, 2014)
# Out:
#     TAVG
# 0  16.56
# 1  21.64
# 2  22.09
# 3  22.33
# 4  22.47
# 5  25.05
#               TAVG
# count  1283.000000
# mean     20.984022
# std       3.577484
# min      11.300000
# 25%      17.805000
# 50%      21.770000
# 75%      23.800000
# max      27.460000
