# %%
from src_1.visualizer import plot_graph, plot_missingdata
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.__version__
# Out:
# '3.4.2'

# %%
TRAIN = 'data/train.csv'
TEST = 'data/test.csv'
RAW = 'data/raw.csv'
raw_data = pd.read_csv(RAW)
train_data = pd.read_csv(TRAIN)
test_data = pd.read_csv(TEST)
# Out:
# /home/tuanhuynh/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3172: DtypeWarning: Columns (59,61,63,65,79,81,83,85,87,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### Thống kê điểm dữ liệu bị mất

# %%
for col in raw_data.columns:
    if 'ATTRIBUTES' in col:
        raw_data.drop([col], axis=1, inplace=True)
        continue
plt.figure(figsize=(30, 10))
plot_missingdata(raw_data, 'Dataset columns with missing values','Column Name','No. of Missing values')
# Out:
# The dataset contains 44.31 % missing values
# ELEVATION      369
# DP01          1516
# DP10          1516
# DP1X          1516
# EMXP          1516
# PRCP          1035
# DSND         11463
# DSNW         10568
# EMSD         11463
# EMSN         10568
# SNOW         10568
# CDSD          4438
# CLDD            71
# HDSD          4652
# HTDD            71
# DYTS         19789
# DYFG         19716
# EVAP         19570
# WDMV         19604
# MNPN         19579
# MXPN         19581
# HN01         19386
# HX01         19388
# LN01         19386
# LX01         19388
# MN01         19386
# MX01         19388
# HN02         19982
# HX02         19983
# LN02         19982
# LX02         19983
# MN02         19982
# MX02         19983
# dtype: int64

# %% [markdown]
# ### Mỗi quan hệ giữa các biến với nhiệt độ

# %%
plot_graph(train_data)
# Out:
# /home/tuanhuynh/College/Year 2/Mathematics Stats/climate-predictor/src_1/visualizer.py:16: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axes = plt.subplots(1, 3)
